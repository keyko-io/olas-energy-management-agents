# %% [markdown]
# # Energy Consumption and Production Analysis
#
# ## 1. Introduction
#
# This notebook presents a preliminary analysis of energy consumption and photovoltaic (PV) energy production data. The goal is to monitor energy usage and determine when the air conditioning should be turned on or off based on the energy balance.
#
# ### Objectives
# - Load and preprocess the historical energy data.
# - Analyze the relationship between energy consumption and production.
# - Implement a simple rule-based system to control the air conditioning.
# - Visualize the results and key metrics.
#
# ## 2. Data Loading and Preprocessing
#
# ### 2.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.2 Load the CSV Data

# %%
# Load the data from the CSV file
file_path = './household_data_15min_singleindex.csv'
data = pd.read_csv(file_path, low_memory=False)

# Display the first few rows of the dataframe
data.head()
# Out:
#           utc_timestamp        cet_cest_timestamp  \
# 0  2014-12-11T17:45:00Z  2014-12-11T18:45:00+0100
# 1  2014-12-11T18:00:00Z  2014-12-11T19:00:00+0100
# 2  2014-12-11T18:15:00Z  2014-12-11T19:15:00+0100
# 3  2014-12-11T18:30:00Z  2014-12-11T19:30:00+0100
# 4  2014-12-11T18:45:00Z  2014-12-11T19:45:00+0100
#
#    DE_KN_industrial1_grid_import  DE_KN_industrial1_pv_1  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
#
#    DE_KN_industrial1_pv_2  DE_KN_industrial2_grid_import  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                            NaN
#
#    DE_KN_industrial2_pv  DE_KN_industrial2_storage_charge  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#    DE_KN_industrial2_storage_decharge  DE_KN_industrial3_area_offices  ...  \
# 0                                 NaN                             NaN  ...
# 1                                 NaN                             NaN  ...
# 2                                 NaN                             NaN  ...
# 3                                 NaN                             NaN  ...
# 4                                 NaN                             NaN  ...
#
#    DE_KN_residential5_refrigerator  DE_KN_residential5_washing_machine  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
#
#    DE_KN_residential6_circulation_pump  DE_KN_residential6_dishwasher  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    DE_KN_residential6_freezer  DE_KN_residential6_grid_export  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    DE_KN_residential6_grid_import  DE_KN_residential6_pv  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
#    DE_KN_residential6_washing_machine  interpolated
# 0                                 NaN           NaN
# 1                                 NaN           NaN
# 2                                 NaN           NaN
# 3                                 NaN           NaN
# 4                                 NaN           NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# ### 2.3 Data Overview

# %%
# Check the data types and missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 71 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   utc_timestamp                        153810 non-null  object
#  1   cet_cest_timestamp                   153810 non-null  object
#  2   DE_KN_industrial1_grid_import        65730 non-null   float64
#  3   DE_KN_industrial1_pv_1               69151 non-null   float64
#  4   DE_KN_industrial1_pv_2               69151 non-null   float64
#  5   DE_KN_industrial2_grid_import        45113 non-null   float64
#  6   DE_KN_industrial2_pv                 47998 non-null   float64
#  7   DE_KN_industrial2_storage_charge     39010 non-null   float64
#  8   DE_KN_industrial2_storage_decharge   39010 non-null   float64
#  9   DE_KN_industrial3_area_offices       57437 non-null   float64
#  10  DE_KN_industrial3_area_room_1        57437 non-null   float64
#  11  DE_KN_industrial3_area_room_2        57437 non-null   float64
#  12  DE_KN_industrial3_area_room_3        57440 non-null   float64
#  13  DE_KN_industrial3_area_room_4        57440 non-null   float64
#  14  DE_KN_industrial3_compressor         57437 non-null   float64
#  15  DE_KN_industrial3_cooling_aggregate  57437 non-null   float64
#  16  DE_KN_industrial3_cooling_pumps      57437 non-null   float64
#  17  DE_KN_industrial3_dishwasher         57439 non-null   float64
#  18  DE_KN_industrial3_ev                 41714 non-null   float64
#  19  DE_KN_industrial3_grid_import        46036 non-null   float64
#  20  DE_KN_industrial3_machine_1          57437 non-null   float64
#  21  DE_KN_industrial3_machine_2          57437 non-null   float64
#  22  DE_KN_industrial3_machine_3          57437 non-null   float64
#  23  DE_KN_industrial3_machine_4          57440 non-null   float64
#  24  DE_KN_industrial3_machine_5          57440 non-null   float64
#  25  DE_KN_industrial3_pv_facade          57437 non-null   float64
#  26  DE_KN_industrial3_pv_roof            57437 non-null   float64
#  27  DE_KN_industrial3_refrigerator       56984 non-null   float64
#  28  DE_KN_industrial3_ventilation        57437 non-null   float64
#  29  DE_KN_public1_grid_import            18197 non-null   float64
#  30  DE_KN_public2_grid_import            4491 non-null    float64
#  31  DE_KN_residential1_dishwasher        63378 non-null   float64
#  32  DE_KN_residential1_freezer           51580 non-null   float64
#  33  DE_KN_residential1_grid_import       63487 non-null   float64
#  34  DE_KN_residential1_heat_pump         63487 non-null   float64
#  35  DE_KN_residential1_pv                63487 non-null   float64
#  36  DE_KN_residential1_washing_machine   63381 non-null   float64
#  37  DE_KN_residential2_circulation_pump  79291 non-null   float64
#  38  DE_KN_residential2_dishwasher        76530 non-null   float64
#  39  DE_KN_residential2_freezer           41000 non-null   float64
#  40  DE_KN_residential2_grid_import       63190 non-null   float64
#  41  DE_KN_residential2_washing_machine   98929 non-null   float64
#  42  DE_KN_residential3_circulation_pump  132839 non-null  float64
#  43  DE_KN_residential3_dishwasher        116384 non-null  float64
#  44  DE_KN_residential3_freezer           114925 non-null  float64
#  45  DE_KN_residential3_grid_export       90218 non-null   float64
#  46  DE_KN_residential3_grid_import       47612 non-null   float64
#  47  DE_KN_residential3_pv                90218 non-null   float64
#  48  DE_KN_residential3_refrigerator      100400 non-null  float64
#  49  DE_KN_residential3_washing_machine   122181 non-null  float64
#  50  DE_KN_residential4_dishwasher        50477 non-null   float64
#  51  DE_KN_residential4_ev                81148 non-null   float64
#  52  DE_KN_residential4_freezer           81147 non-null   float64
#  53  DE_KN_residential4_grid_export       81435 non-null   float64
#  54  DE_KN_residential4_grid_import       81435 non-null   float64
#  55  DE_KN_residential4_heat_pump         49239 non-null   float64
#  56  DE_KN_residential4_pv                81435 non-null   float64
#  57  DE_KN_residential4_refrigerator      43053 non-null   float64
#  58  DE_KN_residential4_washing_machine   49028 non-null   float64
#  59  DE_KN_residential5_dishwasher        94161 non-null   float64
#  60  DE_KN_residential5_grid_import       123211 non-null  float64
#  61  DE_KN_residential5_refrigerator      58254 non-null   float64
#  62  DE_KN_residential5_washing_machine   94161 non-null   float64
#  63  DE_KN_residential6_circulation_pump  86133 non-null   float64
#  64  DE_KN_residential6_dishwasher        56243 non-null   float64
#  65  DE_KN_residential6_freezer           61383 non-null   float64
#  66  DE_KN_residential6_grid_export       66755 non-null   float64
#  67  DE_KN_residential6_grid_import       86133 non-null   float64
#  68  DE_KN_residential6_pv                86133 non-null   float64
#  69  DE_KN_residential6_washing_machine   59136 non-null   float64
#  70  interpolated                         121593 non-null  object
# dtypes: float64(68), object(3)
# memory usage: 83.3+ MB

# %%
# Basic statistics
data.describe()
# Out:
#        DE_KN_industrial1_grid_import  DE_KN_industrial1_pv_1  \
# count                   65730.000000            69151.000000
# mean                   221554.089851             4520.320655
# std                    149026.587296             3287.170985
# min                         0.500000                0.020000
# 25%                     77548.811000             1141.661500
# 50%                    224831.695500             5000.102000
# 75%                    334317.734500             6694.052000
# max                    511112.711000            11001.342000
#
#        DE_KN_industrial1_pv_2  DE_KN_industrial2_grid_import  \
# count            69151.000000                   45113.000000
# mean              3545.186872                    7996.226184
# std               2536.251961                    5129.061810
# min                  0.015000                       0.329000
# 25%                853.954000                    3677.433000
# 50%               3988.004000                    6583.750000
# 75%               5183.133000                   13206.473000
# max               8377.523000                   16699.016000
#
#        DE_KN_industrial2_pv  DE_KN_industrial2_storage_charge  \
# count          47998.000000                      39010.000000
# mean           10728.677060                        826.592343
# std             7625.527968                        424.455449
# min                0.029000                          0.000000
# 25%             2502.448500                        487.899250
# 50%            10549.356000                        920.858500
# 75%            19012.817000                       1116.520750
# max            22122.400000                       1576.598000
#
#        DE_KN_industrial2_storage_decharge  DE_KN_industrial3_area_offices  \
# count                        39010.000000                    57437.000000
# mean                           503.721251                     8489.951637
# std                            254.398333                     4601.592908
# min                              0.000000                        2.738000
# 25%                            304.219000                     4674.052000
# 50%                            569.398000                     8646.140000
# 75%                            670.442250                    12423.205000
# max                            954.553000                    16046.565000
#
#        DE_KN_industrial3_area_room_1  DE_KN_industrial3_area_room_2  ...  \
# count                   57437.000000                   57437.000000  ...
# mean                     3148.657536                   14652.301652  ...
# std                      1769.127257                    8195.769562  ...
# min                         0.618000                       2.055000  ...
# 25%                      1556.158000                    7684.926000  ...
# 50%                      3274.989000                   14851.715000  ...
# 75%                      4723.408000                   21536.734000  ...
# max                      5981.095000                   28679.348000  ...
#
#        DE_KN_residential5_grid_import  DE_KN_residential5_refrigerator  \
# count                   123211.000000                     58254.000000
# mean                      4690.002662                       294.515130
# std                       2612.395098                       176.494473
# min                          0.020000                         0.000000
# 25%                       2254.466000                       134.434000
# 50%                       4758.691000                       300.326500
# 75%                       7195.781500                       447.719500
# max                       8773.800000                       603.771000
#
#        DE_KN_residential5_washing_machine  \
# count                        94161.000000
# mean                           244.463565
# std                            129.832920
# min                              0.000000
# 25%                            141.409000
# 50%                            247.038000
# 75%                            348.330000
# max                            476.462000
#
#        DE_KN_residential6_circulation_pump  DE_KN_residential6_dishwasher  \
# count                         86133.000000                   56243.000000
# mean                            457.495175                      45.881923
# std                             260.065445                      28.797255
# min                               0.034000                       0.000000
# 25%                             252.765000                      18.464000
# 50%                             447.303000                      46.186000
# 75%                             669.106000                      70.654000
# max                             950.744000                      96.078000
#
#        DE_KN_residential6_freezer  DE_KN_residential6_grid_export  \
# count                61383.000000                    66755.000000
# mean                   100.860781                     2178.986341
# std                     34.126776                     1003.652603
# min                      0.005000                        0.110000
# 25%                     93.957000                     1524.210000
# 50%                    104.914000                     1760.510000
# 75%                    127.344500                     3347.620000
# max                    146.692000                     3443.260000
#
#        DE_KN_residential6_grid_import  DE_KN_residential6_pv  \
# count                    86133.000000           86133.000000
# mean                      4208.204466           10042.476028
# std                       1841.653780            6587.062609
# min                          1.010000               0.000000
# 25%                       3252.549000            3919.890000
# 50%                       4555.864000            9563.700000
# 75%                       5406.044000           16670.075000
# max                       7349.309000           20495.400000
#
#        DE_KN_residential6_washing_machine
# count                        59136.000000
# mean                            38.227643
# std                             21.898970
# min                              0.000000
# 25%                             22.275000
# 50%                             35.457000
# 75%                             54.895000
# max                             78.641000
#
# [8 rows x 68 columns]

# %% [markdown]
# ### 2.4 Data Preprocessing

# %%
# Convert timestamp columns to datetime
data['utc_timestamp'] = pd.to_datetime(data['utc_timestamp'], utc=True)
data['cet_cest_timestamp'] = pd.to_datetime(data['cet_cest_timestamp'], utc=True)

data = data[[
    'utc_timestamp', 
    'DE_KN_residential1_dishwasher', 
    'DE_KN_residential1_freezer', 
    'DE_KN_residential1_washing_machine', 
    'DE_KN_residential1_heat_pump',
    'DE_KN_residential1_pv'
]]
# Drop rows with missing values
data.dropna(inplace=True)

# %% [markdown]
# ## 3. Analyzing Energy Consumption and Production
#
# ### 3.1 Calculate Total Consumption and Production

# %%
data['residential1_dishwasher_instant'] = data['DE_KN_residential1_dishwasher'].diff().fillna(0)
data['residential1_freezer_instant'] = data['DE_KN_residential1_freezer'].diff().fillna(0)
data['residential1_washing_machine_instant'] = data['DE_KN_residential1_washing_machine'].diff().fillna(0)
data['residential1_heat_pump_instant'] = data['DE_KN_residential1_heat_pump'].diff().fillna(0)
data['residential1_pv_instant'] = data['DE_KN_residential1_pv'].diff().fillna(0)

data['total_consumption'] = (data['residential1_dishwasher_instant'] +
                             data['residential1_freezer_instant'] +
                             data['residential1_washing_machine_instant'] +
                             data['residential1_heat_pump_instant'])

data['total_production'] = data['DE_KN_residential1_pv'].diff().fillna(0)

# %% [markdown]
# ### 3.2 Determine Air Conditioning State

# %%
# Initialize the air conditioning column with 0
data['air_conditioning_on'] = 0

# Set air conditioning on if production > consumption
data.loc[data['total_production'] > data['total_consumption'], 'air_conditioning_on'] = 1

# Shift the air conditioning state by one period to use the previous period's decision
data['air_conditioning_on'] = data['air_conditioning_on'].shift(1, fill_value=0)

# %% [markdown]
# ## 4. Visualization and Metrics
#
# ### 4.1 Plotting Energy Consumption and Production

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(x='utc_timestamp', y='total_consumption', data=data, label='Total Consumption')
sns.lineplot(x='utc_timestamp', y='total_production', data=data, label='Total Production')
plt.title('Energy Consumption and Production Over Time')
plt.xlabel('Time')
plt.ylabel('Energy (kWh)')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.2 Air Conditioning State Over Time

# %%
data_hourly = data.resample('H', on='utc_timestamp').mean()

# Plot resampled data
plt.figure(figsize=(14, 7))
sns.lineplot(data=data_hourly, x='utc_timestamp', y='total_consumption', label='Total Consumption')
sns.lineplot(data=data_hourly, x='utc_timestamp', y='total_production', label='Total Production')
plt.title('Hourly Energy Consumption and Production Over Time')
plt.xlabel('Time')
plt.ylabel('Energy (kWh)')
plt.legend()
plt.show()
# Out:
# /var/folders/gd/q32w8wgd1bxc7wq53vd9nts80000gn/T/ipykernel_87192/3442675225.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data_hourly = data.resample('H', on='utc_timestamp').mean()

# %% [markdown]
# ### 4.3 Air conditioning State Hourly

# %%
# Apply rolling mean with a window of 60 minutes
data['total_consumption_smooth'] = data['total_consumption'].rolling(window=4).mean()
data['total_production_smooth'] = data['total_production'].rolling(window=4).mean()

# Plot smoothed data
plt.figure(figsize=(14, 7))
sns.lineplot(data=data, x='utc_timestamp', y='total_consumption_smooth', label='Total Consumption (Smoothed)')
sns.lineplot(data=data, x='utc_timestamp', y='total_production_smooth', label='Total Production (Smoothed)')
plt.title('Smoothed Energy Consumption and Production Over Time')
plt.xlabel('Time')
plt.ylabel('Energy (kWh)')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.4 - Air Conditioning State - Zoom in

# %%
# Select a specific week to visualize
start_date = '2016-06-01'
end_date = '2016-06-07'
data_week = data[(data['utc_timestamp'] >= start_date) & (data['utc_timestamp'] <= end_date)]

# Plot data for the specific week
plt.figure(figsize=(14, 7))
sns.lineplot(data=data_week, x='utc_timestamp', y='total_consumption', label='Total Consumption')
sns.lineplot(data=data_week, x='utc_timestamp', y='total_production', label='Total Production')
plt.title('Energy Consumption and Production Over One Week')
plt.xlabel('Time')
plt.ylabel('Energy (kWh)')
plt.legend()
plt.show()

# Plot air conditioning state for the specific week with event plot
plt.figure(figsize=(14, 2))
plt.eventplot(data_week[data_week['air_conditioning_on'] == 1]['utc_timestamp'], lineoffsets=1, colors='red')
plt.eventplot(data_week[data_week['air_conditioning_on'] == 0]['utc_timestamp'], lineoffsets=0, colors='blue')
plt.title('Air Conditioning State Over One Week')
plt.xlabel('Time')
plt.yticks([0, 1], ['OFF', 'ON'])
plt.show()

# %% [markdown]
# ### 4.3 Distribution of Consumption and Production

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data['total_consumption'], kde=True, color='blue', label='Total Consumption')
sns.histplot(data['total_production'], kde=True, color='orange', label='Total Production')
plt.title('Distribution of Energy Consumption and Production')
plt.xlabel('Energy (kWh)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.4 Metrics

# %%
# First, create a column indicating when air_conditioning_on changes state
data['change'] = (data['air_conditioning_on'] != data['air_conditioning_on'].shift(1)).astype(int)

# Assign a group number to each block of consecutive values
data['group'] = data['change'].cumsum()

# Filter periods where air conditioning is on (air_conditioning_on == 1)
on_periods = data[data['air_conditioning_on'] == 1]
off_periods = data[data['air_conditioning_on'] == 0]

# Calculate the duration of each continuous period where air conditioning is on
on_periods['duration'] = on_periods.groupby('group')['utc_timestamp'].transform(lambda x: (x.max() - x.min()).total_seconds() / 3600)
off_periods['duration'] = off_periods.groupby('group')['utc_timestamp'].transform(lambda x: (x.max() - x.min()).total_seconds() / 3600)

# Calculate the average time the air conditioning is continuously on
average_on_time = on_periods['duration'].mean()
average_off_time = off_periods['duration'].mean()
# Out:
# /var/folders/gd/q32w8wgd1bxc7wq53vd9nts80000gn/T/ipykernel_87192/3607908551.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   on_periods['duration'] = on_periods.groupby('group')['utc_timestamp'].transform(lambda x: (x.max() - x.min()).total_seconds() / 3600)
# /var/folders/gd/q32w8wgd1bxc7wq53vd9nts80000gn/T/ipykernel_87192/3607908551.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   off_periods['duration'] = off_periods.groupby('group')['utc_timestamp'].transform(lambda x: (x.max() - x.min()).total_seconds() / 3600)

# %%
# Calculate the percentage of time the air conditioning was on
ac_on_percentage = data['air_conditioning_on'].mean() * 100

# Calculate the mean and standard deviation of consumption and production
mean_consumption = data['total_consumption'].mean()
std_consumption = data['total_consumption'].std()
mean_production = data['total_production'].mean()
std_production = data['total_production'].std()

# Calculate Peak Demand and Production
peak_demand = data['total_consumption'].max()
peak_production = data['total_production'].max()

print(f"Air Conditioning On Percentage: {ac_on_percentage:.2f}%")
print(f"Mean Consumption: {mean_consumption:.2f} kWh (Std: {std_consumption:.2f} kWh)")
print(f"Mean Production: {mean_production:.2f} kWh (Std: {std_production:.2f} kWh)")
print(f"Peak Demand: {peak_demand:.2f} kWh")
print(f"Peak Production: {peak_production:.2f} kWh")
print(f"Average time the air conditioning is continuously on: {average_on_time:.2f} hours")
print(f"Average time the air conditioning is continuously off: {average_off_time:.2f} hours")
# Out:
# Air Conditioning On Percentage: 30.69%
# Mean Consumption: 0.21 kWh (Std: 0.26 kWh)
# Mean Production: 0.22 kWh (Std: 0.43 kWh)
# Peak Demand: 2.51 kWh
# Peak Production: 2.13 kWh
# Average time the air conditioning is continuously on: 6.41 hours
# Average time the air conditioning is continuously off: 15.13 hours

# %% [markdown]
# ## 5. Next Steps
# - Integrate real-time data monitoring.
# - Develop and test machine learning models to predict energy consumption and production.
# - Implement autonomous agents to optimize energy usage and interact with PEAQ blockchain.
